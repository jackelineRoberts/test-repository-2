# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Jackeline

# %% [markdown]
# ## *I am interested in data science because I enjoy being a part of new technologies!*

# %% [markdown]
# ### Simple calculation

# %%
25 + 80
# Out:
# 105

# %% [markdown]
# --- 1. First item
# --- 2. Second item
# --- 3. Third item
# ---At the command prompt, type `nano` .
